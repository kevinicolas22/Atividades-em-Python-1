# %%
matriz = [[0,0,1],[1,0,0],]
condicoes = []
def determinante(a):
  for i in range (0,len(matriz)):
    condicao = True
    for j in range (0,len(matriz[0])):
      if(matriz[i][j] != 0):
        condicao = False
    condicoes.append(condicao)
  if(True in condicoes):
    print('Todos os elementos da linha é igual à zero, o determinante da matriz é nulo.')
  else:
    print('O determinante da matriz não é nulo') 
determinante(matriz)
# Out:
# O determinante da matriz não é nulo

# %%
matriz = [[0,0,1],[1,0,0],]
def verificacao_linhas(matriz):
  condicoes = []
  for i in range (0,len(matriz),1):
    condicao = True
    for j in range (0,len(matriz[0]),1):
      if(matriz[i][j] != 0):
        condicao = False
    condicoes.append(condicao)

    for i in range (0,len(matriz),1):
      condicao = True
      for j in range (0,len(matriz[0]),1):
          if(matriz[j][i] != 0):
              condicao = False
      condicoes.append(condicao)
    return condicoes

condicoes1 =  verificacao_linhas(matriz)
print(condicoes1)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# c:\Users\kevin\Documents\Programação\Meus Projetos\Exercícios-em-Python\Atividades em Python - 1\Matrizes.ipynb Célula: 2 in <cell line: 19>()
#      <a href='vscode-notebook-cell:/c%3A/Users/kevin/Documents/Programa%C3%A7%C3%A3o/Meus%20Projetos/Exerc%C3%ADcios-em-Python/Atividades%20em%20Python%20-%201/Matrizes.ipynb#W1sZmlsZQ%3D%3D?line=15'>16</a>       condicoes.append(condicao)
#      <a href='vscode-notebook-cell:/c%3A/Users/kevin/Documents/Programa%C3%A7%C3%A3o/Meus%20Projetos/Exerc%C3%ADcios-em-Python/Atividades%20em%20Python%20-%201/Matrizes.ipynb#W1sZmlsZQ%3D%3D?line=16'>17</a>     return condicoes
# ...
